# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/threads_data_indonesia.csv")
df.head()
# Out:
#    #                                    NAME FOLLOWERS     ER    COUNTRY  \
# 0  1               Ridwan Kamil @ridwankamil      431K  1.11%  Indonesia
# 1  2  Deddy Corbuzier, Ph.D @mastercorbuzier    401.8K  0.67%  Indonesia
# 2  3              Raditya Dika @raditya_dika    367.3K  0.63%  Indonesia
# 3  4           anya geraldine @anyageraldine    332.3K  0.62%  Indonesia
# 4  5                     Luna Maya @lunamaya    313.3K  0.43%  Indonesia
#
#                          TOPIC OF INFLUENCE POTENTIAL REACH
# 0                                  Politics          129.3K
# 1                     Entertainment & Music          120.5K
# 2               Entertainment & Music Funny          110.2K
# 3                          Product Showcase           99.7K
# 4  Beauty & Self Care Entertainment & Music             94K

# %%
df.drop(columns=["#", "COUNTRY", "POTENTIAL REACH"], inplace=True)
df.head()
# Out:
#                                      NAME FOLLOWERS     ER  \
# 0               Ridwan Kamil @ridwankamil      431K  1.11%
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier    401.8K  0.67%
# 2              Raditya Dika @raditya_dika    367.3K  0.63%
# 3           anya geraldine @anyageraldine    332.3K  0.62%
# 4                     Luna Maya @lunamaya    313.3K  0.43%
#
#                          TOPIC OF INFLUENCE
# 0                                  Politics
# 1                     Entertainment & Music
# 2               Entertainment & Music Funny
# 3                          Product Showcase
# 4  Beauty & Self Care Entertainment & Music

# %%
df.isnull().sum()
# Out:
# NAME                  0
# FOLLOWERS             0
# ER                    0
# TOPIC OF INFLUENCE    1
# dtype: int64

# %%
print(df["TOPIC OF INFLUENCE"].value_counts())
# Out:
# TOPIC OF INFLUENCE
# Entertainment & Music                                        17
# Fashion & Accessories                                         8
# Education                                                     7
# Food                                                          6
# Product Showcase                                              5
# Sports                                                        4
# Entertainment & Music Arts & Crafts                           4
# Beauty & Self Care                                            4
# Fitness & Health                                              3
# Finance                                                       3
# News                                                          2
# Fashion & Accessories Product Showcase                        2
# Travel                                                        2
# Food Travel                                                   2
# Entertainment & Music Media                                   1
# Entertainment & Music Funny                                   1
# Politics                                                      1
# Beauty & Self Care Entertainment & Music                      1
# family                                                        1
# Life & Society                                                1
# Art Arts & Crafts                                             1
# Auto and Vehicles                                             1
# Acting & Drama family Outdoor Activity Education              1
# Animals                                                       1
# Lifestyle & Society                                           1
# News & Media                                                  1
# Nature                                                        1
# Education Life & Society                                      1
# Finance Product Showcase                                      1
# Education Upskilling                                          1
# Education Product Showcase                                    1
# Beauty & Self Care Fashion & Accessories Product Showcase     1
# Travel Food Entertainment & Music                             1
# Religion                                                      1
# Education Technology                                          1
# Photography Product Showcase Auto and Vehicles                1
# Funny                                                         1
# Entertainment & Music Acting & Drama                          1
# Entertainment & Music Life & Society Product Showcase         1
# family Outdoor Activity Travel                                1
# Beauty & Self Care Fashion & Accessories Sports               1
# Entertainment & Music Education                               1
# Photography Art & Crafts                                      1
# Politics Life & Society                                       1
# Name: count, dtype: int64

# %%
def map_topic_7(topic):
    topic = str(topic).lower()
    if any(word in topic for word in ["entertainment", "music", "funny", "drama", "art", "craft"]):
        return "Entertainment & Arts"
    elif any(word in topic for word in ["fashion", "beauty", "accessories", "self care"]):
        return "Fashion & Beauty"
    elif any(word in topic for word in ["food", "travel", "family", "life"]):
        return "Lifestyle & Travel"
    elif any(word in topic for word in ["education", "politics", "news", "society"]):
        return "Education & Society"
    elif any(word in topic for word in ["fitness", "health", "outdoor"]):
        return "Fitness & Health"
    elif any(word in topic for word in ["finance", "business", "tech", "technology"]):
        return "Tech & Finance"
    else:
        return "Others"

df["TOPIC_CATEGORY"] = df["TOPIC OF INFLUENCE"].apply(map_topic_7)

# %%
print(df["TOPIC_CATEGORY"].value_counts())
# Out:
# TOPIC_CATEGORY
# Entertainment & Arts    32
# Fashion & Beauty        16
# Lifestyle & Travel      16
# Others                  15
# Education & Society     14
# Tech & Finance           4
# Fitness & Health         3
# Name: count, dtype: int64

# %%
missing_topic = df[df["TOPIC OF INFLUENCE"].isna()]
print(missing_topic)
# Out:
#                                   NAME FOLLOWERS     ER TOPIC OF INFLUENCE  \
# 40  Benjamin Master Adhisurya @iben_ma     90.2K  1.22%                NaN
#
#    TOPIC_CATEGORY
# 40         Others

# %%
df.head(10)
# Out:
#                                      NAME FOLLOWERS     ER  \
# 0               Ridwan Kamil @ridwankamil      431K  1.11%
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier    401.8K  0.67%
# 2              Raditya Dika @raditya_dika    367.3K  0.63%
# 3           anya geraldine @anyageraldine    332.3K  0.62%
# 4                     Luna Maya @lunamaya    313.3K  0.43%
# 5             Gisella Anastasia @gisel_la    234.4K      -
# 6             Shopee Indonesia @shopee_id    231.1K  0.11%
# 7             Tasya Farasya @tasyafarasya    221.5K  0.24%
# 8                     Dinda Hauw @dindahw    212.1K  0.82%
# 9                Cipeng | TIRTA @dr.tirta    186.7K  0.11%
#
#                          TOPIC OF INFLUENCE        TOPIC_CATEGORY
# 0                                  Politics   Education & Society
# 1                     Entertainment & Music  Entertainment & Arts
# 2               Entertainment & Music Funny  Entertainment & Arts
# 3                          Product Showcase                Others
# 4  Beauty & Self Care Entertainment & Music  Entertainment & Arts
# 5                                    family    Lifestyle & Travel
# 6                          Product Showcase                Others
# 7                        Beauty & Self Care      Fashion & Beauty
# 8                        Beauty & Self Care      Fashion & Beauty
# 9                          Fitness & Health      Fitness & Health

# %%
df.drop(columns=["TOPIC OF INFLUENCE"], inplace=True)
df.head()
# Out:
#                                      NAME FOLLOWERS     ER  \
# 0               Ridwan Kamil @ridwankamil      431K  1.11%
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier    401.8K  0.67%
# 2              Raditya Dika @raditya_dika    367.3K  0.63%
# 3           anya geraldine @anyageraldine    332.3K  0.62%
# 4                     Luna Maya @lunamaya    313.3K  0.43%
#
#          TOPIC_CATEGORY
# 0   Education & Society
# 1  Entertainment & Arts
# 2  Entertainment & Arts
# 3                Others
# 4  Entertainment & Arts

# %%
print(df["TOPIC_CATEGORY"].value_counts())
# Out:
# TOPIC_CATEGORY
# Entertainment & Arts    32
# Fashion & Beauty        16
# Lifestyle & Travel      16
# Others                  15
# Education & Society     14
# Tech & Finance           4
# Fitness & Health         3
# Name: count, dtype: int64

# %%
def parse_number(value):
    if isinstance(value, str):
        value = value.strip().upper().replace(",", "")
        if 'M' in value:
            return float(value.replace('M', '')) * 1_000_000
        elif 'K' in value:
            return float(value.replace('K', '')) * 1_000
        else:
            try:
                return float(value)
            except:
                return None
    return value

df['FOLLOWERS'] = df['FOLLOWERS'].apply(parse_number)

# %%
def parse_percentage(value):
    if isinstance(value, str) and '%' in value:
        return float(value.replace('%', '')) / 100
    return value

df['ER'] = df['ER'].apply(parse_percentage)

# %%
df.head()
# Out:
#                                      NAME  FOLLOWERS      ER  \
# 0               Ridwan Kamil @ridwankamil   431000.0  0.0111
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier   401800.0  0.0067
# 2              Raditya Dika @raditya_dika   367300.0  0.0063
# 3           anya geraldine @anyageraldine   332300.0  0.0062
# 4                     Luna Maya @lunamaya   313300.0  0.0043
#
#          TOPIC_CATEGORY
# 0   Education & Society
# 1  Entertainment & Arts
# 2  Entertainment & Arts
# 3                Others
# 4  Entertainment & Arts

# %%
ER = df["ER"].unique()
print(ER)
# Out:
# [0.0111 0.0067 0.0063 0.0062 0.0043 '-' 0.0011 0.0024 0.008199999999999999
#  0.0172 0.004699999999999999 0.0018 0.0066 0.0023 0.0028000000000000004
#  0.011000000000000001 0.003 0.0141 0.0118 0.0068000000000000005 0.0033
#  0.0143 0.0138 0.0004 0.0070999999999999995 0.0139 0.0042 0.0097 0.0025
#  0.0037 0.002 0.0052 0.016 0.0008 0.012199999999999999 0.0176
#  0.0017000000000000001 0.005600000000000001 0.0012 0.004 0.0032 0.0016
#  0.0053 0.006 0.0079 0.0213 0.0006 0.0021 0.0147 0.001 0.0015 0.0026
#  0.0031 0.0154 0.006999999999999999 0.0076 0.0148 0.0069
#  0.0034000000000000002 0.0019 0.0009 0.0014000000000000002 0.0013 0.0044
#  0.0048 0.0074 0.015700000000000002 0.006500000000000001 0.0095 0.0131
#  0.0002 0.0005]

# %%
df = df[df['ER'] != '-']
df['ER'] = pd.to_numeric(df['ER'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            96 non-null     object
#  1   FOLLOWERS       96 non-null     float64
#  2   ER              96 non-null     float64
#  3   TOPIC_CATEGORY  96 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 3.8+ KB

# %%
def classify_type(followers):
    if followers < 10_000:
        return 'Nano'
    elif followers < 50_000:
        return 'Micro'
    elif followers < 500_000:
        return 'Mid-tier'
    elif followers < 1_000_000:
        return 'Macro'
    else:
        return 'Mega'

df['TYPE_INFLUENCER'] = df['FOLLOWERS'].apply(classify_type)

# %%
df.head()
# Out:
#                                      NAME  FOLLOWERS      ER  \
# 0               Ridwan Kamil @ridwankamil   431000.0  0.0111
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier   401800.0  0.0067
# 2              Raditya Dika @raditya_dika   367300.0  0.0063
# 3           anya geraldine @anyageraldine   332300.0  0.0062
# 4                     Luna Maya @lunamaya   313300.0  0.0043
#
#          TOPIC_CATEGORY TYPE_INFLUENCER
# 0   Education & Society        Mid-tier
# 1  Entertainment & Arts        Mid-tier
# 2  Entertainment & Arts        Mid-tier
# 3                Others        Mid-tier
# 4  Entertainment & Arts        Mid-tier

# %%
rate_map = {
    'Nano': 500,       
    'Micro': 1000,      
    'Mid-tier': 2000, 
    'Macro': 3000,     
    'Mega': 5000       
}

df['CPE'] = df['TYPE_INFLUENCER'].map(rate_map)

# %%
df.head()
# Out:
#                                      NAME  FOLLOWERS      ER  \
# 0               Ridwan Kamil @ridwankamil   431000.0  0.0111
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier   401800.0  0.0067
# 2              Raditya Dika @raditya_dika   367300.0  0.0063
# 3           anya geraldine @anyageraldine   332300.0  0.0062
# 4                     Luna Maya @lunamaya   313300.0  0.0043
#
#          TOPIC_CATEGORY TYPE_INFLUENCER   CPE
# 0   Education & Society        Mid-tier  2000
# 1  Entertainment & Arts        Mid-tier  2000
# 2  Entertainment & Arts        Mid-tier  2000
# 3                Others        Mid-tier  2000
# 4  Entertainment & Arts        Mid-tier  2000

# %%
df['ENGAGEMENT'] = (df['ER'] * df['FOLLOWERS'])

# %%
df.head()
# Out:
#                                      NAME  FOLLOWERS      ER  \
# 0               Ridwan Kamil @ridwankamil   431000.0  0.0111
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier   401800.0  0.0067
# 2              Raditya Dika @raditya_dika   367300.0  0.0063
# 3           anya geraldine @anyageraldine   332300.0  0.0062
# 4                     Luna Maya @lunamaya   313300.0  0.0043
#
#          TOPIC_CATEGORY TYPE_INFLUENCER   CPE  ENGAGEMENT
# 0   Education & Society        Mid-tier  2000     4784.10
# 1  Entertainment & Arts        Mid-tier  2000     2692.06
# 2  Entertainment & Arts        Mid-tier  2000     2313.99
# 3                Others        Mid-tier  2000     2060.26
# 4  Entertainment & Arts        Mid-tier  2000     1347.19

# %%
df['ESTIMATED_COST'] = df['ENGAGEMENT'] * df['CPE']
df.head()
# Out:
#                                      NAME  FOLLOWERS      ER  \
# 0               Ridwan Kamil @ridwankamil   431000.0  0.0111
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier   401800.0  0.0067
# 2              Raditya Dika @raditya_dika   367300.0  0.0063
# 3           anya geraldine @anyageraldine   332300.0  0.0062
# 4                     Luna Maya @lunamaya   313300.0  0.0043
#
#          TOPIC_CATEGORY TYPE_INFLUENCER   CPE  ENGAGEMENT  ESTIMATED_COST
# 0   Education & Society        Mid-tier  2000     4784.10       9568200.0
# 1  Entertainment & Arts        Mid-tier  2000     2692.06       5384120.0
# 2  Entertainment & Arts        Mid-tier  2000     2313.99       4627980.0
# 3                Others        Mid-tier  2000     2060.26       4120520.0
# 4  Entertainment & Arts        Mid-tier  2000     1347.19       2694380.0

# %%
df.drop(columns=["FOLLOWERS"], inplace=True)
df.head()
# Out:
#                                      NAME      ER        TOPIC_CATEGORY  \
# 0               Ridwan Kamil @ridwankamil  0.0111   Education & Society
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier  0.0067  Entertainment & Arts
# 2              Raditya Dika @raditya_dika  0.0063  Entertainment & Arts
# 3           anya geraldine @anyageraldine  0.0062                Others
# 4                     Luna Maya @lunamaya  0.0043  Entertainment & Arts
#
#   TYPE_INFLUENCER   CPE  ENGAGEMENT  ESTIMATED_COST
# 0        Mid-tier  2000     4784.10       9568200.0
# 1        Mid-tier  2000     2692.06       5384120.0
# 2        Mid-tier  2000     2313.99       4627980.0
# 3        Mid-tier  2000     2060.26       4120520.0
# 4        Mid-tier  2000     1347.19       2694380.0

# %%
df.drop(columns=["ER"], inplace=True)
df.head()
# Out:
#                                      NAME        TOPIC_CATEGORY  \
# 0               Ridwan Kamil @ridwankamil   Education & Society
# 1  Deddy Corbuzier, Ph.D @mastercorbuzier  Entertainment & Arts
# 2              Raditya Dika @raditya_dika  Entertainment & Arts
# 3           anya geraldine @anyageraldine                Others
# 4                     Luna Maya @lunamaya  Entertainment & Arts
#
#   TYPE_INFLUENCER   CPE  ENGAGEMENT  ESTIMATED_COST
# 0        Mid-tier  2000     4784.10       9568200.0
# 1        Mid-tier  2000     2692.06       5384120.0
# 2        Mid-tier  2000     2313.99       4627980.0
# 3        Mid-tier  2000     2060.26       4120520.0
# 4        Mid-tier  2000     1347.19       2694380.0

# %%
df.drop(columns=["TYPE_INFLUENCER", "CPE"], inplace=True)
df.head()

# %%
output_path = '../data/fix/threads_cleaned.csv'  # Sesuaikan nama file sesuai platform
df.to_csv(output_path, index=False)
